# %%
import autogen

config_list = {
    'model': 'llama3.1',
    'base_url': 'http://localhost:11434/v1',
    'api_key': 'ollama',
}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import autogen
#       3 config_list = {
#       4     'model': 'llama3.1',
#       5     'base_url': 'http://localhost:11434/v1',
#       6     'api_key': 'ollama',
#       7 }
#
# ModuleNotFoundError: No module named 'autogen'

# %%
text_assistant = autogen.ConversableAgent(
    'assistant', 
    system_message='You are an agent designed to redact personal information from any text provided to you.' 
                   'Your task is to identify and replace any personal information with stars (**).'
                   'This includes, but is not limited to, names, phone numbers, email addresses, physical addresses, social security numbers, and any other personally identifiable information (PII).'
                   'Ensure that the redaction is consistent throughout the text.'
                   'An evaluation agent will review your work and provide you with feedback or tips on how to improve. Understand their feedback and make the necessary changes to your redacted text.'
                   'You must output the redacted text only and not address or respond to any agents directly.',
    llm_config=config_list, 
    human_input_mode='NEVER',
    code_execution_config=False
)

evaluation = autogen.ConversableAgent(
    'evaluation-agent',
    system_message='You are an evaluation agent tasked with reviewing text to ensure that all personal information has been correctly redacted.'
                   'Your job is to verify that any personal information (such as names, phone numbers, email addresses, physical addresses, social security numbers, and other personally identifiable information) has been replaced with stars (**).'
                   'If you find any personal information that has not been redacted or if the redaction is inconsistent, you should flag the specific issues and provide feedback.'
                   'Ensure that the redaction is thorough and meets the required standards.',
    llm_config=config_list,
    human_input_mode='NEVER',
    code_execution_config=False
)

user_proxy = autogen.UserProxyAgent(
    'user_proxy', 
    human_input_mode='NEVER',
    code_execution_config=False
)

chat_outline = {
    'message': f'To ensure that the requirement for transport of the academic year 2024-25 is met for all students seeking admission for the 1st year (CET Students) and students seeking continuation of the services of the Buses already being availed by the present 1st & 2nd year students, and also from the 3rd year students at SOE who will be migrating to Campus 4 to the 4th year from Campus 3, there is a requirement to have confirmation from the students'
                'To get the exact requirement from all the existing students, all the students of SOE, COPS, BPT, AHS & Nursing who require Transport Facility, to pay the Full Transport Fees by the end of their respective academic year 2023-24. This also applies to the present students who are availing the transport. The students who do not pay the transport fees will be considered as not requiring the transport arrangements for the academic year 2024-25. The Copy of the notification of the Charges with the respective routes applicable is attached to this email.'
                'Students of SOE 2nd, 3rd & 4th year, who require transport are required to apply online by logging into the ERP with their passwords and click on Transport and fill in the required data and pay the amount also online. All the students will submit their requirements for transport by 16 August 2024. '
                'Respective Dean / Principal\'s are requested to communicate the above to all the staff under them for strict compliance. For students, the same may be communicated to all through their respective groups or Google  Forms.',
    }

# %%
conversation_state = 1
speakers = []
def text_redact_selection_func(speaker: autogen.AssistantAgent, groupchat: autogen.GroupChat):
    global conversation_state
    if speaker == user_proxy and conversation_state == 1:
        conversation_state += 1
        speakers.append(text_assistant.name)
        return text_assistant
    elif speaker == text_assistant and conversation_state == 2:
        conversation_state += 1
        speakers.append(evaluation.name)
        return evaluation
    elif speaker == evaluation and conversation_state == 3:
        conversation_state += 1
        speakers.append(text_assistant.name)
        return text_assistant

text_redaction_chat = autogen.GroupChat(
    agents=[user_proxy, text_assistant, evaluation],
    speaker_selection_method=text_redact_selection_func,
    messages=[],
    max_round=4
)

text_redaction_manager = autogen.GroupChatManager(
    groupchat=text_redaction_chat, llm_config=config_list
)

# %%
text_redaction_chats = user_proxy.initiate_chat(
    text_redaction_manager,
    message=chat_outline['message']
)
# Out:
# user_proxy (to chat_manager):
#
# To ensure that the requirement for transport of the academic year 2024-25 is met for all students seeking admission for the 1st year (CET Students) and students seeking continuation of the services of the Buses already being availed by the present 1st & 2nd year students, and also from the 3rd year students at SOE who will be migrating to Campus 4 to the 4th year from Campus 3, there is a requirement to have confirmation from the studentsTo get the exact requirement from all the existing students, all the students of SOE, COPS, BPT, AHS & Nursing who require Transport Facility, to pay the Full Transport Fees by the end of their respective academic year 2023-24. This also applies to the present students who are availing the transport. The students who do not pay the transport fees will be considered as not requiring the transport arrangements for the academic year 2024-25. The Copy of the notification of the Charges with the respective routes applicable is attached to this email.Students of SOE 2nd, 3rd & 4th year, who require transport are required to apply online by logging into the ERP with their passwords and click on Transport and fill in the required data and pay the amount also online. All the students will submit their requirements for transport by 16 August 2024. Respective Dean / Principal's are requested to communicate the above to all the staff under them for strict compliance. For students, the same may be communicated to all through their respective groups or Google  Forms.
#
# --------------------------------------------------------------------------------
#
# Next speaker: assistant
#
# [autogen.oai.client: 09-04 18:58:12] {329} WARNING - Model llama3.1 is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# assistant (to chat_manager):
#
# To ensure that the requirement for transport of the academic year **20**24-25 is met for all students seeking admission for the 1st year (**CET Students**) and students seeking continuation of the services of the Buses already being availed by the present 1st & 2nd year students, and also from the 3rd year students at SOE who will be migrating to Campus 4 to the 4th year from Campus 3, there is a requirement to have confirmation from the students
#
# To get the exact requirement from all the existing students, all the students of SOE, COPS, BPT, AHS & Nursing who require Transport Facility, to pay the Full Transport Fees by the end of their respective academic year **20**23-24. This also applies to the present students who are availing the transport. The students who do not pay the transport fees will be considered as not requiring the transport arrangements for the academic year **20**24-25.
#
# The Copy of the notification of the Charges with the respective routes applicable is attached to this *** .
#
# Students of SOE 2nd, 3rd & 4th year, who require transport are required to apply online by logging into the ERP with their passwords and click on Transport and fill in the required data and pay the amount also online. All the students will submit their requirements for transport by **16 August 20**24.
#
# Respective Dean / Principal's are requested to communicate the above to all the staff under them for strict compliance. For students, the same may be communicated to all through their respective groups or Google *** .
#
# --------------------------------------------------------------------------------
#
# Next speaker: evaluation-agent
#
# [autogen.oai.client: 09-04 18:58:42] {329} WARNING - Model llama3.1 is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# evaluation-agent (to chat_manager):
#
# I've reviewed the provided text and have identified several instances of personal information that still needs to be redacted or corrected:
#
# 1. Phone number/email address: The phrase "Click on Transport" should be redacted as it reveals a specific function or button in the ERP system, potentially containing personal details.
#
# 2. Date of Birth/Registration: The academic years mentioned in the text should be replaced with stars (**). There are two instances where academic year numbers were left unchanged:
# 	* Academic year **20**24-25
# 	* Academic year **20**23-24
#
# These specific details can still compromise personal information and could potentially identify individuals associated with educational institutions.
#
# 3. Institutional Names: These names provide insight into the institutions involved, which may be a concern for those who value anonymity in academic matters:
# 	* SOE (School of Engineering)
# 	* COPS
# 	* BPT
# 	* AHS & Nursing
#
# While these names alone do not breach personal details, they might reveal relationships and interactions potentially relevant to data protection compliance.
#
# 4. Specific Requirements: Revealing specific routes and transport arrangements could also leak information about students' routines and places of residence.
#
# 5. Google Form: The reference to using 'Google ***' instead of a fully redacted version should be replaced with stars (**). This maintains the redaction standard while ensuring that sensitive details remain concealed.
#
# Corrected text:
#
# To ensure that the requirement for transport of the academic year ***20***24-25 is met for all students seeking admission for the 1st year (CET Students) and students seeking continuation of the services of the Buses already being availed by the present 1st & 2nd year students, and also from the 3rd year students at SOE who will be migrating to Campus 4 to the 4th year from Campus 3, there is a requirement to have confirmation from the students.
#
# To get the exact requirement from all the existing students, all the students of SOE, COPS, BPT, AHS & Nursing who require Transport Facility, to pay the Full Transport Fees by the end of their respective academic year ***20***23-24. This also applies to the present students who are availing the transport. The students who do not pay the transport fees will be considered as not requiring the transport arrangements for the academic year ***20***24-25.
#
# The Copy of the notification of the Charges with the respective routes applicable is attached to this ***.
#
# Students of SOE 2nd, 3rd & 4th year, who require transport are required to apply online by logging into the ERP with their passwords and click on Transport and fill in the required data and pay the amount also online. All the students will submit their requirements for transport by **16 August **20****.
#
# Respective Dean / Principal's are requested to communicate the above to all the staff under them for strict compliance. For students, the same may be communicated to all through their respective groups or Google ***.
#
# **Redaction Suggested:**
# In addition to correcting the identified issues above, the entire text should undergo a thorough review to eliminate any inadvertently revealed sensitive information and make sure that redactions are consistently applied according to the required standards.
#
# --------------------------------------------------------------------------------
#
# Next speaker: assistant
#
# [autogen.oai.client: 09-04 18:59:01] {329} WARNING - Model llama3.1 is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# assistant (to chat_manager):
#
# To ensure that the requirement for transport of the academic year **20***-**25 is met for all students seeking admission for the 1st year (**CET Students**) and students seeking continuation of the services of the Buses already being availed by the present 1st & 2nd year students, and also from the 3rd year students at **** who will be migrating to Campus **4** to the 4th year from Campus **3**, there is a requirement to have confirmation from the students
#
# To get the exact requirement from all the existing students, all the students of **** , **** , **** , **** & *** who require Transport Facility, to pay the Full Transport Fees by the end of their respective academic year **20***-**24. This also applies to the present students who are availing the transport. The students who do not pay the transport fees will be considered as not requiring the transport arrangements for the academic year **20***-**25.
#
# The Copy of the notification of the Charges with the respective routes applicable is attached to this ***** .
#
# Students of **** 2nd, 3rd & 4th year, who require transport are required to apply online by logging into the ERP with their passwords and click on ***** fill in the required data and pay the amount also online. All the students will submit their requirements for transport by **16 August ***** .
#
# Respective Dean / Principal's are requested to communicate the above to all the staff under them for strict compliance. For students, the same may be communicated to all through their respective groups or ***** .
#
# --------------------------------------------------------------------------------
